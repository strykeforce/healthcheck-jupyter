# %% [markdown]
# # 2026 REBUILT Health Check

# %%
from pathlib import Path
import sys

lib = Path("../../src")
sys.path.append(str(lib.resolve(strict=True)))

import healthcheck
import pandas as pd
from matplotlib import pyplot as plt
import itertools
import requests

# %%
try:
    hc
except NameError:
    hc = healthcheck.load_roborio()
    path = hc.save()
    print(f"Health Check data saved to \"{path.relative_to(Path.cwd())}\"")
# Out:
# Health Check data saved to "history\2026-05-02-0828.pkl.xz"

# %%
#hc = healthcheck.load_healthcheck("history/2026-03-29-0819.pkl.xz")
hc.cases
# Out:
#            name  talon_set      type  output  duration
# case
# 0        Swerve          0      time    0.20   2000000
# 1        Swerve          0      time    1.00   2000000
# 2        Swerve          0      time   -0.20   2000000
# 3        Swerve          0      time   -1.00   2000000
# 4        Swerve         10      time    0.20   2000000
# 5        Swerve         10      time    1.00   2000000
# 6        Swerve         10      time   -0.20   2000000
# 7        Swerve         10      time   -1.00   2000000
# 8        Intake         20      time   -0.10   2000000
# 9        Intake         20      time    0.10   2000000
# 10       Intake         20      time    0.90   2000000
# 11    Spindexer         35      time   -0.10   2000000
# 12    Spindexer         35      time    0.10   2000000
# 13    Spindexer         35      time    0.60   2000000
# 14      Indexer         30      time   -0.10   2000000
# 15      Indexer         30      time    0.10   2000000
# ...

# %%
hc.plot_talons(cases = [1,3], talons = [0,1,2,3])
hc.plot_talons(cases = [0,2], talons = [0,1,2,3])

# %%
hc.plot_talons(cases = [4,6], talons = [10,11,12,13])
hc.plot_talons(cases = [5,7], talons = [10,11,12,13])

# %%
hc.plot_talons(cases = [8,9,10], talons = [20,21])

# %%
hc.plot_talons(cases = [11,12,13], talons = [35])

# %%
hc.plot_talons(cases = [14,15,16], talons = [30])

# %%
hc.plot_talons(cases = [17,18,19], talons = [45,46])

# %%
hc.plot_talons(cases = [20,21], talons = [50])

# %%
hc.plot_talons(cases = [22,23], talons = [40])

# %%
hc.plot_talons(cases = [24,25], talons = [25,26])

# %% [markdown]
# ##
