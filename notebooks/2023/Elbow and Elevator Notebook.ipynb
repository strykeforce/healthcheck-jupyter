# %%
from pathlib import Path
import sys

lib = Path("../../src")
sys.path.append(str(lib.resolve(strict=True)))

import healthcheck
import pandas as pd
from matplotlib import pyplot as plt
import itertools
import requests

# %%
try:
    hc
except NameError:
    hc = healthcheck.load_roborio()
    path = hc.save()
    print(f"Health Check data saved to \"{path.relative_to(Path.cwd())}\"")
# Out:
# Health Check data saved to "history\2023-04-08-1225.pkl.xz"

# %%
hc.cases
# Out:
#                    name  talon_set      type  output  duration
# case
# 0        ElbowSubsystem         33  position     0.3     41000
# 1        ElbowSubsystem         33  position    -0.3     41000
# 2        ElbowSubsystem         33  position     0.3     41000
# 3     ElevatorSubsystem         31  position    -0.3     12542
# 4     ElevatorSubsystem         31  position     0.3     12542

# %%
hc.plot_talons((-15,15), (-50,50), (-7000, 7000), 10000, 100000, 10000,cases = [0,1,2], talons = [33])

# %%
hc.plot_talons((-10,10), (-35,35), (-10000, 10000), 10000, 100000, 10000,cases = [3,4], talons = [31,32])
