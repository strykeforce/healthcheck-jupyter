# %% [markdown]
# # 2023 CHARGED UP Health Check

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from pathlib import Path
import sys

lib = Path("../../src")
sys.path.append(str(lib.resolve(strict=True)))
import healthcheck

# %% [markdown]
# ## Load Data
# After the health check is run on the robot, the cell below will download the data from the roboRIO into this notebook if not already loaded. The health check data is saved into the `history` subdirectory.

# %%
try:
    hc
except NameError:
    #hc = healthcheck.load_roborio()
    #path = hc.save()
    #print(f"Health Check data saved to \"{path.relative_to(Path.cwd())}\"")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 try:
# ----> 2     hc
#       3 except NameError:
#       4     #hc = healthcheck.load_roborio()
#
# NameError: name 'hc' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2     hc
#       3 except NameError:
#       4     #hc = healthcheck.load_roborio()
# ----> 5     path = hc.save()
#       6     print(f"Health Check data saved to \"{path.relative_to(Path.cwd())}\"")
#
# NameError: name 'hc' is not defined

# %% [markdown]
# Uncomment and run the cell below if you want to load historical data instead.

# %%
 hc = healthcheck.load_healthcheck("history/2023-10-21-1512.pkl.xz")

# %% [markdown]
# ## List Health Checks
# To assist in plotting health checks, the cell below will list all of the health check cases. Feel free to delete this after setting up health checks.

# %%
hc.cases
# Out:
#                    name  talon_set      type  output  duration
# case
# 0        DriveSubsystem          0      time     0.2   2000000
# 1        DriveSubsystem          0      time     1.0   2000000
# 2        DriveSubsystem          0      time    -0.2   2000000
# 3        DriveSubsystem          0      time    -1.0   2000000
# 4        DriveSubsystem         10      time     0.2   2000000
# 5        DriveSubsystem         10      time     1.0   2000000
# 6        DriveSubsystem         10      time    -0.2   2000000
# 7        DriveSubsystem         10      time    -1.0   2000000
# 8         HandSubsystem         40  position    -0.2      1200
# 9         HandSubsystem         40  position     0.2      1200
# 10        HandSubsystem         41      time     0.7   3000000
# 11        HandSubsystem         41      time    -0.7   3000000
# 12      IntakeSubsystem         20      time     0.5   3000000
# 13      IntakeSubsystem         20      time    -0.5   3000000
# 14      IntakeSubsystem         21  position    -0.5      2000
# 15      IntakeSubsystem         21  position     0.5      2000
# 16    ShoulderSubsystem         30  position     0.2      4100
# 17    ShoulderSubsystem         30  position    -0.2      4100
# 18       ElbowSubsystem         33  position     0.3     41000
# 19       ElbowSubsystem         33  position    -0.3     41000
# 20       ElbowSubsystem         33  position     0.3     41000
# 21    ElevatorSubsystem         31  position    -0.3     12542
# 22    ElevatorSubsystem         31  position     0.3     12542

# %% [markdown]
# ## Drive Subsystem
# **Note:** the cases assigned to plot in the cell below assume that the `DriveSubsystem` is the first Subsystem tested.

# %%
hc.plot_talons(cases=[0,1,2,3,4,5], talons=[0,1,2,3], voltage=True, stator_current=False, title="DriveSubsystem Azimuth Talons")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 hc.plot_talons(cases=[0,1,2,3,4,5], talons=[0,1,2,3], voltage=True, stator_current=False, title="DriveSubsystem Azimuth Talons")
#
# TypeError: HealthCheck.plot_talons() missing 6 required positional arguments: 'supply_ylim', 'stator_ylim', 'speed_ylim', 'SupplyLineY', 'StatorLineY', and 'SpeedLineY'

# %%
hc.plot_talons(cases=[6,7,8,9,10,11], talons=[10,11,12,13], title="DriveSubsystem Drive Talons")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 hc.plot_talons(cases=[6,7,8,9,10,11], talons=[10,11,12,13], title="DriveSubsystem Drive Talons")
#
# TypeError: HealthCheck.plot_talons() missing 6 required positional arguments: 'supply_ylim', 'stator_ylim', 'speed_ylim', 'SupplyLineY', 'StatorLineY', and 'SpeedLineY'

# %% [markdown]
# ## Another Subsystem
# Add cells and plots below as desired.

# %%
# hc.plot_talons(cases=[...], talons=[...])
