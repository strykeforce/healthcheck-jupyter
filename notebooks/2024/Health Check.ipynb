# %% [markdown]
# # 2024 CHARGED UP Health Check

# %%
from pathlib import Path
import sys

lib = Path("../../src")
sys.path.append(str(lib.resolve(strict=True)))

import healthcheck
import pandas as pd
from matplotlib import pyplot as plt
import itertools
import requests

# %%
try:
    hc
except NameError:
    hc = healthcheck.load_roborio()
    path = hc.save()
    print(f"Health Check data saved to \"{path.relative_to(Path.cwd())}\"")
# Out:
# Health Check data saved to "history\2024-10-26-1656.pkl.xz"

# %%
#hc = healthcheck.load_healthcheck("history/2024-09-24-1816.pkl.xz")
hc.cases
# Out:
#           name  talon_set      type  output  duration
# case
# 0       Swerve          0      time     0.2   2000000
# 1       Swerve          0      time     1.0   2000000
# 2       Swerve          0      time    -0.2   2000000
# 3       Swerve          0      time    -1.0   2000000
# 4       Swerve         10      time     0.2   2000000
# 5       Swerve         10      time     1.0   2000000
# 6       Swerve         10      time    -0.2   2000000
# 7       Swerve         10      time    -1.0   2000000
# 8       Intake         20      time     0.5   3000000
# 9       Intake         20      time    -0.5   3000000
# 10    Magazine         25      time     0.2   3000000
# 11    Magazine         25      time    -0.2   3000000
# 12    Magazine         25      time     0.9   3000000
# 13    Magazine         25      time    -0.9   3000000
# 14     Shooter         40      time     0.2   3000000
# 15     Shooter         40      time    -0.2   3000000
# ...

# %%
hc.plot_talons(cases = [1,3], talons = [0,1,2,3])
hc.plot_talons(cases = [0,2], talons = [0,1,2,3])

# %%
hc.plot_talons(cases = [4,6], talons = [10,11,12,13])
hc.plot_talons(cases = [5,7], talons = [10,11,12,13])

# %%
hc.plot_talons(cases = [8,9], talons = [20])

# %%
hc.plot_talons(cases = [10,11,12,13], talons = [25])

# %%
hc.plot_talons(cases = [14,15,16,17,18], talons = [40,41])

# %%
hc.plot_talons(cases = [19,20], talons = [30])

# %%
hc.plot_talons(cases = [21,22], talons = [35])

# %%
hc.plot_talons(cases = [23,24], talons = [50,51])

# %%
hc.plot_talons(cases = [25,26], talons = [52,53])

# %% [markdown]
# ##
