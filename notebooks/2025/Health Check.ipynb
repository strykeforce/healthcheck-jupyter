# %% [markdown]
# # 2025 REEFSCAPE Health Check

# %%
from pathlib import Path
import sys

lib = Path("../../src")
sys.path.append(str(lib.resolve(strict=True)))

import healthcheck
import pandas as pd
from matplotlib import pyplot as plt
import itertools
import requests

# %%
try:
    hc
except NameError:
    hc = healthcheck.load_roborio()
    path = hc.save()
    print(f"Health Check data saved to \"{path.relative_to(Path.cwd())}\"")
# Out:
# Health Check data saved to "history\2025-10-18-1505.pkl.xz"

# %%
#hc = healthcheck.load_healthcheck("history/2025-07-11-1144.pkl.xz")
hc.cases
# Out:
#           name  talon_set      type  output  duration
# case
# 0       Swerve          0      time    0.20   2000000
# 1       Swerve          0      time    1.00   2000000
# 2       Swerve          0      time   -0.20   2000000
# 3       Swerve          0      time   -1.00   2000000
# 4       Swerve         10      time    0.20   2000000
# 5       Swerve         10      time    1.00   2000000
# 6       Swerve         10      time   -0.20   2000000
# 7       Swerve         10      time   -1.00   2000000
# 8       Funnel         40      time    0.10   2000000
# 9       Funnel         40      time    0.75   2000000
# 10       Coral         35      time    0.10   2000000
# 11       Coral         35      time    1.00   2000000
# 12       Algae         30      time    0.50   2000000
# 13       Algae         30      time    0.04   2000000
# 14       Algae         30      time   -1.00   2000000
# 15    Elevator         20  position   -0.05        10
# 16    Elevator         20  position    0.10        10
# 17     Biscuit         25  position    0.05        20
# 18     Biscuit         25  position   -0.10        20

# %%
hc.plot_talons(cases = [1,3], talons = [0,1,2,3])
hc.plot_talons(cases = [0,2], talons = [0,1,2,3])

# %%
hc.plot_talons(cases = [4,6], talons = [10,11,12,13])
hc.plot_talons(cases = [5,7], talons = [10,11,12,13])

# %%
hc.plot_talons(cases = [8,9], talons = [40])

# %%
hc.plot_talons(cases = [10,11], talons = [35])

# %%
hc.plot_talons(cases = [12,13,14], talons = [30])

# %%
hc.plot_talons(cases = [15,16], talons = [20,21])

# %%
hc.plot_talons(cases = [17,18], talons = [25])

# %% [markdown]
# ##
